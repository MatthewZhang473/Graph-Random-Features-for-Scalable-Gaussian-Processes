# %% [markdown]
# # Synthetic Multi-Modal Data Generation - 1000x1000 Mesh Graph
#
# This notebook generates synthetic multi-modal data on a 1000x1000 regular mesh graph (1M nodes) for testing graph-based interpolation methods.
#
# **Key Features:**
# - 1000×1000 regular mesh grid (1M nodes)
# - Multi-modal function with multiple Gaussian peaks and noise
# - 4-connected mesh graph with unit edge weights
# - Consistent node indexing for graph-based methods
# - Random sparse sampling for training data
# - Same data structure as wind interpolation example

# %%
# =============================================================================
# IMPORTS AND CONFIGURATION
# =============================================================================

import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse
import time

# Configuration
GRID_SIZE = 1000        # 1000x1000 grid (1M nodes)
NOISE_STD = 0.1         # Standard deviation of noise
TRAINING_RATIO = 0.01   # 1% of nodes for training (10K points)
RANDOM_SEED = 42        # For reproducibility
N_PEAKS = 5             # Number of Gaussian peaks

np.random.seed(RANDOM_SEED)

print(f"Configuration:")
print(f"  Grid size: {GRID_SIZE}×{GRID_SIZE} = {GRID_SIZE**2:,} nodes")
print(f"  Number of peaks: {N_PEAKS}")
print(f"  Training ratio: {TRAINING_RATIO*100:.1f}%")
print(f"  Expected training points: {int(GRID_SIZE**2 * TRAINING_RATIO):,}")
print(f"  Noise std: {NOISE_STD}")
print(f"  Random seed: {RANDOM_SEED}")
# Out:
# Configuration:
#   Grid size: 1000×1000 = 1,000,000 nodes
#   Number of peaks: 5
#   Training ratio: 1.0%
#   Expected training points: 10,000
#   Noise std: 0.1
#   Random seed: 42

# %%
# =============================================================================
# MESH GRAPH CONSTRUCTION UTILITIES
# =============================================================================

def grid_index(i, j, n_rows, n_cols):
    """Flatten (i,j) -> node id"""
    return i * n_cols + j

def build_mesh_graph(n_rows, n_cols):
    """Build a 4-connected mesh graph efficiently using sparse matrices"""
    n_nodes = n_rows * n_cols
    rows, cols, data = [], [], []
    
    # 4-connected neighbors: right, left, down, up
    directions = [(0, 1), (0, -1), (1, 0), (-1, 0)]
    
    for i in range(n_rows):
        for j in range(n_cols):
            node_id = grid_index(i, j, n_rows, n_cols)
            for di, dj in directions:
                ni, nj = i + di, j + dj
                if 0 <= ni < n_rows and 0 <= nj < n_cols:
                    neighbor_id = grid_index(ni, nj, n_rows, n_cols)
                    rows.append(node_id)
                    cols.append(neighbor_id)
                    data.append(1.0)
    
    A = sparse.coo_matrix((data, (rows, cols)), shape=(n_nodes, n_nodes))
    return A.tocsr()

print("Mesh graph utilities defined")
# Out:
# Mesh graph utilities defined

# %%
# =============================================================================
# MULTI-MODAL SYNTHETIC DATA GENERATION
# =============================================================================

def generate_multimodal_function(n_rows, n_cols, n_peaks=5, noise_std=0.1):
    """
    Generate a multi-modal function with multiple Gaussian peaks
    
    Parameters:
    -----------
    n_rows : int
        Number of rows in the grid
    n_cols : int
        Number of columns in the grid  
    n_peaks : int
        Number of Gaussian peaks to generate
    noise_std : float
        Standard deviation of additive noise
        
    Returns:
    --------
    y : np.ndarray
        Function values at grid points (flattened)
    coord_mapping : np.ndarray
        (x, y) coordinates for each node
    peak_info : list
        Information about each peak (center, amplitude, width)
    """
    # Create coordinate grids
    x = np.linspace(-2, 2, n_cols)
    y = np.linspace(-2, 2, n_rows)
    X, Y = np.meshgrid(x, y)
    
    # Initialize function as zeros
    f_clean = np.zeros_like(X)
    
    # Generate random peaks
    peak_info = []
    for i in range(n_peaks):
        # Random center location
        center_x = np.random.uniform(-1.5, 1.5)
        center_y = np.random.uniform(-1.5, 1.5)
        
        # Random amplitude (some positive, some negative for more complexity)
        amplitude = np.random.uniform(0.5, 2.0) * (1 if i < n_peaks//2 else np.random.choice([-1, 1]))
        
        # Random width (make some peaks wider/narrower)
        sigma_x = np.random.uniform(0.2, 0.6)
        sigma_y = np.random.uniform(0.2, 0.6)
        
        # Random rotation angle
        theta = np.random.uniform(0, 2*np.pi)
        
        peak_info.append({
            'center': (center_x, center_y),
            'amplitude': amplitude,
            'sigma': (sigma_x, sigma_y),
            'rotation': theta
        })
        
        # Generate rotated Gaussian
        a = np.cos(theta)**2 / (2*sigma_x**2) + np.sin(theta)**2 / (2*sigma_y**2)
        b = -np.sin(2*theta) / (4*sigma_x**2) + np.sin(2*theta) / (4*sigma_y**2)
        c = np.sin(theta)**2 / (2*sigma_x**2) + np.cos(theta)**2 / (2*sigma_y**2)
        
        dx = X - center_x
        dy = Y - center_y
        
        gaussian = amplitude * np.exp(-(a*dx**2 + 2*b*dx*dy + c*dy**2))
        f_clean += gaussian
    
    # Add noise
    noise = np.random.normal(0, noise_std, f_clean.shape)
    f_noisy = f_clean + noise
    
    # Flatten to match node indexing
    y_values = f_noisy.flatten()
    
    # Create coordinate mapping
    coord_mapping = np.zeros((n_rows * n_cols, 2))
    for i in range(n_rows):
        for j in range(n_cols):
            node_id = grid_index(i, j, n_rows, n_cols)
            coord_mapping[node_id, 0] = X[i, j]
            coord_mapping[node_id, 1] = Y[i, j]
    
    return y_values, coord_mapping, peak_info

print("Multi-modal data generation function defined")
# Out:
# Multi-modal data generation function defined

# %%
# =============================================================================
# BUILD GRAPH AND GENERATE DATA
# =============================================================================

print("Building mesh graph and generating multi-modal synthetic data...")
start_time = time.time()

# Build mesh graph
A = build_mesh_graph(GRID_SIZE, GRID_SIZE)
print(f"Graph construction completed in {time.time() - start_time:.2f} seconds")

# Generate multi-modal synthetic data
data_start = time.time()
y, coord_mapping, peak_info = generate_multimodal_function(GRID_SIZE, GRID_SIZE, N_PEAKS, NOISE_STD)

# Normalize data
y_mean, y_std = np.mean(y), np.std(y)
y_normalized = (y - y_mean) / y_std

# Generate training data
n_nodes = GRID_SIZE * GRID_SIZE
X = np.arange(n_nodes)
n_training = int(n_nodes * TRAINING_RATIO)
X_train = np.sort(np.random.choice(n_nodes, size=n_training, replace=False))
y_train = y_normalized[X_train]

# Save dataset
np.savez(f'synthetic_multimodal_{GRID_SIZE}x{GRID_SIZE}.npz',
         A_data=A.data, A_indices=A.indices, A_indptr=A.indptr, A_shape=A.shape,
         X=X, y=y_normalized, y_mean=y_mean, y_std=y_std,
         X_train=X_train, y_train=y_train, coord_mapping=coord_mapping,
         peak_info=peak_info, grid_size=GRID_SIZE, n_peaks=N_PEAKS,
         noise_std=NOISE_STD, training_ratio=TRAINING_RATIO, random_seed=RANDOM_SEED)

print(f"\n✅ Multi-modal dataset saved to 'synthetic_multimodal_{GRID_SIZE}x{GRID_SIZE}.npz'")
print(f"✅ Grid: {GRID_SIZE}×{GRID_SIZE}, Peaks: {N_PEAKS}, Training: {len(X_train):,}")

# Visualization
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
y_2d = y_normalized.reshape((GRID_SIZE, GRID_SIZE))

# Full function
im1 = axes[0,0].imshow(y_2d, extent=[-2, 2, -2, 2], cmap='viridis', origin='lower')
axes[0,0].set_title('Multi-Modal Function')
plt.colorbar(im1, ax=axes[0,0])

# Training points
train_coords = coord_mapping[X_train]
axes[0,1].scatter(train_coords[:, 0], train_coords[:, 1], c=y_train, cmap='plasma', s=1)
axes[0,1].set_title(f'Training Points ({len(X_train):,})')

# Distribution
axes[1,0].hist(y_normalized, bins=50, alpha=0.7)
axes[1,0].set_title('Function Value Distribution')

# Peak locations
axes[1,1].imshow(y_2d, extent=[-2, 2, -2, 2], cmap='viridis', origin='lower', alpha=0.7)
for i, peak in enumerate(peak_info):
    axes[1,1].scatter(peak['center'][0], peak['center'][1], 
                     c='red', s=100, marker='x', linewidth=3)
    axes[1,1].text(peak['center'][0], peak['center'][1], f'{i+1}', 
                  fontsize=12, color='white', ha='center', va='center')
axes[1,1].set_title('Peak Locations')

plt.tight_layout()
plt.show()

print(f"Peak information:")
for i, peak in enumerate(peak_info):
    print(f"  Peak {i+1}: center=({peak['center'][0]:.2f}, {peak['center'][1]:.2f}), amp={peak['amplitude']:.2f}")
# Out:
# Building mesh graph and generating multi-modal synthetic data...
# Graph construction completed in 1.85 seconds
#
# ✅ Multi-modal dataset saved to 'synthetic_multimodal_1000x1000.npz'
# ✅ Grid: 1000×1000, Peaks: 5, Training: 10,000
# Peak information:
#   Peak 1: center=(-0.38, 1.35), amp=1.60
#   Peak 2: center=(-1.33, 1.10), amp=1.40
#   Peak 3: center=(1.00, -0.86), amp=-0.77
#   Peak 4: center=(-1.43, 0.07), amp=1.10
#   Peak 5: center=(0.86, -0.90), amp=1.27
